# %% [markdown]
# ### Project 2020
# ###### Machine Learning and Statistics
# ###### Submission Date: January 8th, 2021
#
# #### Instructions
# In this project you must create a web service that uses machine learning to make predictions based on the data set powerproduction available on Moodle. The goal is to
# produce a model that accurately predicts wind turbine power output from wind speed
# values, as in the data set. You must then develop a web service that will respond with
# predicted power values based on speed values sent as HTTP requests. Your submission
# must be in the form of a git repository containing, at a minimum, the following items:
# 1. Jupyter notebook that trains a model using the data set. In the notebook you
# should explain your model and give an analysis of its accuracy.
# 2. Python script that runs a web service based on the model, as above.
# 3. Dockerfile to build and run the web service in a container.
# 4. Standard items in a git repository such as a README.

# %% [markdown]
# # Predicting Wind Turbine Power from Wind Speed Values
#
# ### Importing the Packages
#
# Firstly the packages that are used hereafter for creating the two models: one in Sci-kit Learn Linear Regression and one in Tenserflow package's Keras Linear Regression.
#
# There are additional packages in Numpy, Pandas, Matplotlib and Seaborn that are used for moving elements to array, transform data sets and plotting the data in visual outputs.

# %%
#importing the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import tensorflow
from tensorflow import keras as kr
from tensorflow.keras import layers

# %% [markdown]
# ### Load Data
#
# Secondly the data set as part of this assignment needs to be imported as a csv file and converted using Pandas package to be analyzed and plotted here.

# %%
# inputting the powerproduction csv file
input_file = "powerproduction.csv"
# using pandas dataframes read_csv to read file
df = pd.read_csv(input_file, header = 0)
df = df._get_numeric_data()

# %% [markdown]
# ### Plotting the Data Set using MatplotLib.Plot
#
# Once the data is imported and loaded we can then use the numpy packages to convert the dataframe as df to two numpy arrays for the speed and power sub sets. We can then plot this in a scatter plot to show its visualization.

# %%
#using numpy arrays to strip the columns to arrays
numpy_array = df.to_numpy()
x = numpy_array
# plotting the data set.
plt.plot(x[:,0], x[:,1], 'o')

# %% [markdown]
# The data set shows a curve trajecoty with a linear progression in the data set noticeable on first view.
#
# ### Plotting the Data Set using seaborn.pairplot()
#
# Seaborn packages allow further plotting and representation fo the data in better graphical formats that matplotlib's plots as shown above.
#
# Below are a series of seaborn plots. The first is a distribution plot of the entire data set values and it is clearly varying on both sub sets power and speed and we can further analyze these in separate graphs in the following example.

# %%
# using seaborn as sns to output distribution plot
sns.distplot(df)
# Out:
# c:\users\suppo\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The seaborn pairplot() functions splits the sub sets into both histograms and scatter plots and show a full picture of the speed versus power.
#
# With the wind speed mapping on to the wind power the graphs show that wind speed can clearly impact wind power, as would be expected.

# %%
sns.pairplot(df)
#saving file for displaying the graphical output of the dataset.
plt.savefig('pairplot.png')

# %% [markdown]
# The seaborn regplot() allows map speed on the x axis and power on the y axis with a simple linear regression plot. This shows that the models most fitting for the analysis of this dataset would be to perform machine models on linear regression.

# %%
# seaborns regression plot showing the linear nature of the dataset
sns.regplot(x="speed", y="power", data=df)

# %% [markdown]
# The models chosen for this assignment in analyzing the powerproduction data set are Sci-kit Learn's and Keras' linear regression machine learning models.
#
# ## skLearn Model
# ### Importing Linear Model functions
#
# Scikit learn is a commonly used python compatible package for machine learning models around regression, classification, clustering and more and for this model generation its linear_model module is going to be used for predicting the linear nature of the power production dataset.

# %%
# importing scikit learns linear model package 
#for calculating linear regression
import sklearn.linear_model as lin

# %% [markdown]
# ### Preprocessing Data
#
# To model the set we can strip the data set into separate numpy arrays using the pandas dataframe dropna() function. The arrays are split into x and y with x being the primary set being used hereafter for predict or mappting on to the data in the power sub set. The numpy array is then reshaped as part of the stripping using the reshape() function.

# %%
# splitting the data set into separate arrays
windspeed = df[["speed", "power"]].dropna()
x = windspeed["speed"].to_numpy()
y = windspeed["power"].to_numpy()

x = x.reshape(-1, 1)

# %% [markdown]
# The newly shaped x will now be used for modelling the linear regression.
#
# ### Model
#
# The model is simply to be called with the sci-kit learn LinerarRegression function. It is then fitted to the x, y arrays.

# %%
model = lin.LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# The model intercept is the mean value of Y when x = 0 and as such we can see it outlined below.

# %%
i = model.intercept_
i
# Out:
# -11.498929411767072

# %% [markdown]
# The model coefficients are beneficial for highlighting the potential change in the mean response when there are changes in the data, providing all other elements remain the same. The model coefficients for this dataset output as 4.79* as seen.

# %%
c = model.coef_
c
# Out:
# array([4.79252047])

# %% [markdown]
# The model score is a relatively high 0.73* considering the optimum is 1.0 and shows the consideration for linear regression in this dataset may be justified.

# %%
r= model.score(x, y)
r
# Out:
# 0.7277077554596567

# %% [markdown]
# ### Predicting the Data Set

# %% [markdown]
# The next step is to formulate the predict function which is a function that will input the X array for speed and use p as outlined below. P is a 2D array of the models intercept and coefficient as outlined above. P is passed through function and multiplied with the parameters of the user inputted X and then added to itself to produce a prediction on the Y value.

# %%
p = [model.intercept_, model.coef_[0]]
p
# Out:
# [-11.498929411767072, 4.792520474329507]

# %%
def f(x, p):
    return p[0] + x * p[1]

# %% [markdown]
# Passing the parameter 16.0 into the new function outputs a figure of 65.18*.

# %%
f(16.0, p)
# Out:
# 65.18139817750503

# %% [markdown]
# This f function can be parsed into a further prediction function to validate it further. Looking at the plot printed previously it is clear that the function predicts the value in the Power dataset from the inputted speed very closely.

# %%
def predict(x):
       return f(x,p)

# %%
print(predict(16.0))
print(predict(20.0))
print(predict(25.0))
# Out:
# 65.18139817750503
# 84.35148007482306
# 108.3140824464706

# %%
plt.plot(x, y, 'o')

# %% [markdown]
# ## Keras Model
# ### Preprocessing
# ### Splitting the Data Set
#
# For the second example we can split the data set into a 80/20 split for a train/test model style. Splitting the data sets allows a further testing of the algorithm to see it accuracies with reduce randomised outputs.
#
# Scikit Learn has a model_selection module that enables split the data set, in this case the speed sub set from above as x.

# %%
#importing scikin model selection and train_test_split for splitting x.
from sklearn.model_selection import train_test_split
X_train20, X_test20 = train_test_split(x, test_size=0.20)

# %% [markdown]
# ### Scaling the Data Set

# %% [markdown]
# We can then scaler this data to fit correctly using the StandardScaler() function within Scikit's preprocessing module. This optimised the data set for testing.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# fitting the 80% Training to the scaler.
scaler.fit(X_train20)
# Out:
# StandardScaler()

# %% [markdown]
# ### Forming Train and Test Data Sets
#
# The train and testing data sets of the Speed sub set are going to be passed through f below to form the Y passing through the model.

# %%
f = lambda x: 3.0 * x + 1.0

# %% [markdown]
# The X_train20 and X_test20 data arrays from above are transformed using the scaler.transform() function to create the final modelled X_train and X_test functions. The Y_train and Y_test data sets are passed through the f calculation above to simulate the Power data as above.

# %%
#transforming the train and test X sets into the new Y sets for modelling.
X_train = scaler.transform(X_train20)
X_test = scaler.transform(X_test20)
Y_train = f(X_train)
Y_test = f(X_test)

# %% [markdown]
# The (X_train, Y_train) and (X_test, Y_test) pairs of arrays will for the analysis of the keras model for linear regression below.
#
# ### Model
#
# Using Keras models functions below will allow the creation of a model to test the train and test datasets above.

# %%
# keras model extracted from Keras tutorials and MachineLearningMastery articles.
model = kr.models.Sequential()
#adding layers, shape, activation point, kernels and bias initializers to the model.
model.add(kr.layers.Dense(1, input_shape=(1,), activation="linear", kernel_initializer='ones', bias_initializer='zeros'))
#compiling and including the optimizer and loss functions into model of adam and mean_squared_error
model.compile('adam', loss='mean_squared_error')

# %%
#fitting the model to the X_train and Y_train with epochs =300
model.fit(X_train, Y_train, epochs=300)
# Out:
# Epoch 1/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.8619
# Epoch 2/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.7881
# Epoch 3/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.5696
# Epoch 4/300
# 13/13 [==============================] - 0s 2ms/step - loss: 4.9475
# Epoch 5/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.5681
# Epoch 6/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.6283
# Epoch 7/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.3600
# Epoch 8/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.5442
# Epoch 9/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.2537
# Epoch 10/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.3951
# Epoch 11/300
# 13/13 [==============================] - 0s 2ms/step - loss: 4.2972
# Epoch 12/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.1435
# Epoch 13/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.9328
# Epoch 14/300
# 13/13 [==============================] - 0s 2ms/step - loss: 3.8602
# Epoch 15/300
# 13/13 [==============================] - 0s 1ms/step - loss: 4.2023
# Epoch 16/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.8598
# Epoch 17/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.8126
# Epoch 18/300
# 13/13 [==============================] - 0s 2ms/step - loss: 3.7836
# Epoch 19/300
# 13/13 [==============================] - 0s 2ms/step - loss: 3.5627
# Epoch 20/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.6318
# Epoch 21/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.5794
# Epoch 22/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.4778
# Epoch 23/300
# 13/13 [==============================] - 0s 2ms/step - loss: 3.5987
# Epoch 24/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.4963
# Epoch 25/300
# 13/13 [==============================] - 0s 2ms/step - loss: 3.4614
# Epoch 26/300
# 13/13 [==============================] - 0s 2ms/step - loss: 3.1943
# Epoch 27/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.2588
# Epoch 28/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.1742
# Epoch 29/300
# 13/13 [==============================] - 0s 2ms/step - loss: 3.1776
# Epoch 30/300
# 13/13 [==============================] - 0s 2ms/step - loss: 3.1116
# Epoch 31/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.0909
# Epoch 32/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.0266
# Epoch 33/300
# 13/13 [==============================] - 0s 2ms/step - loss: 2.9285
# Epoch 34/300
# 13/13 [==============================] - 0s 2ms/step - loss: 2.9807
# Epoch 35/300
# 13/13 [==============================] - 0s 1ms/step - loss: 3.1626
# Epoch 36/300
# 13/13 [==============================] - 0s 2ms/step - loss: 2.8647
# Epoch 37/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.8222
# Epoch 38/300
# 13/13 [==============================] - 0s 2ms/step - loss: 2.8222
# Epoch 39/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.8224
# Epoch 40/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.7155
# Epoch 41/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.5338
# Epoch 42/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.4920
# Epoch 43/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.3745
# Epoch 44/300
# 13/13 [==============================] - 0s 2ms/step - loss: 2.5432
# Epoch 45/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.5032
# Epoch 46/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.2987
# Epoch 47/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.4131
# Epoch 48/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.2822
# Epoch 49/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.2121
# Epoch 50/300
# 13/13 [==============================] - 0s 2ms/step - loss: 2.2235
# Epoch 51/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.0991
# Epoch 52/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.0944
# Epoch 53/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.1878
# Epoch 54/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.9327
# Epoch 55/300
# 13/13 [==============================] - 0s 2ms/step - loss: 2.0403
# Epoch 56/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.9127
# Epoch 57/300
# 13/13 [==============================] - 0s 1ms/step - loss: 2.0610
# Epoch 58/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.8699
# Epoch 59/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.8814
# Epoch 60/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.8974
# Epoch 61/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.8311
# Epoch 62/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.7671
# Epoch 63/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.8069
# Epoch 64/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.7153
# Epoch 65/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.6191
# Epoch 66/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.8086
# Epoch 67/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.6244
# Epoch 68/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.6729
# Epoch 69/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.5024
# Epoch 70/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5827
# Epoch 71/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.5385
# Epoch 72/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.4973
# Epoch 73/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.4662
# Epoch 74/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.4389
# Epoch 75/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.4719
# Epoch 76/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.4169
# Epoch 77/300
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3562
# Epoch 78/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.3420
# Epoch 79/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.4157
# Epoch 80/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2522
# Epoch 81/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.3147
# Epoch 82/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.2074
# Epoch 83/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2405
# Epoch 84/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.1507
# Epoch 85/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.1652
# Epoch 86/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.1320
# Epoch 87/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.1263
# Epoch 88/300
# 13/13 [==============================] - 0s 2ms/step - loss: 1.1258
# Epoch 89/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.1040
# Epoch 90/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.0679
# Epoch 91/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.1011
# Epoch 92/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.0156
# Epoch 93/300
# 13/13 [==============================] - 0s 3ms/step - loss: 1.0127
# Epoch 94/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.9492
# Epoch 95/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.9775
# Epoch 96/300
# 13/13 [==============================] - 0s 1ms/step - loss: 1.0031
# Epoch 97/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8984
# Epoch 98/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.9076
# Epoch 99/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8506
# Epoch 100/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8722
# Epoch 101/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8508
# Epoch 102/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8726
# Epoch 103/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.8415
# Epoch 104/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8719
# Epoch 105/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8038
# Epoch 106/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7841
# Epoch 107/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7841
# Epoch 108/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7428
# Epoch 109/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7027
# Epoch 110/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7077
# Epoch 111/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6551
# Epoch 112/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7023
# Epoch 113/300
# 13/13 [==============================] - ETA: 0s - loss: 0.642 - 0s 1ms/step - loss: 0.6814
# Epoch 114/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6789
# Epoch 115/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6470
# Epoch 116/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6607
# Epoch 117/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5860
# Epoch 118/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6196
# Epoch 119/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5989
# Epoch 120/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5743
# Epoch 121/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5371
# Epoch 122/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5366
# Epoch 123/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5524
# Epoch 124/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5102
# Epoch 125/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5070
# Epoch 126/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5261
# Epoch 127/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4975
# Epoch 128/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4735
# Epoch 129/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5000
# Epoch 130/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4779
# Epoch 131/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4579
# Epoch 132/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4081
# Epoch 133/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4319
# Epoch 134/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4213
# Epoch 135/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4044
# Epoch 136/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3868
# Epoch 137/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4075
# Epoch 138/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3761
# Epoch 139/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3748
# Epoch 140/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3408
# Epoch 141/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3576
# Epoch 142/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3203
# Epoch 143/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3521
# Epoch 144/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3433
# Epoch 145/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3307
# Epoch 146/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3240
# Epoch 147/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3081
# Epoch 148/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3044
# Epoch 149/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2838
# Epoch 150/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2796
# Epoch 151/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2798
# Epoch 152/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2853
# Epoch 153/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2571
# Epoch 154/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2452
# Epoch 155/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2531
# Epoch 156/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2533
# Epoch 157/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2353
# Epoch 158/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2351
# Epoch 159/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2267
# Epoch 160/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2280
# Epoch 161/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2149
# Epoch 162/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2009
# Epoch 163/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2010
# Epoch 164/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2043
# Epoch 165/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2032
# Epoch 166/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1996
# Epoch 167/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1825
# Epoch 168/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1737
# Epoch 169/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1760
# Epoch 170/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1691
# Epoch 171/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1553
# Epoch 172/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1620
# Epoch 173/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1532
# Epoch 174/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1545
# Epoch 175/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1569
# Epoch 176/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1395
# Epoch 177/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1384
# Epoch 178/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1234
# Epoch 179/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1338
# Epoch 180/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1300
# Epoch 181/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1180
# Epoch 182/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1220
# Epoch 183/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1084
# Epoch 184/300
# 13/13 [==============================] - ETA: 0s - loss: 0.108 - 0s 1ms/step - loss: 0.1128
# Epoch 185/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1148
# Epoch 186/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1017
# Epoch 187/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1047
# Epoch 188/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0986
# Epoch 189/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1000
# Epoch 190/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0963
# Epoch 191/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0841
# Epoch 192/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0874
# Epoch 193/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0835
# Epoch 194/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0819
# Epoch 195/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0793
# Epoch 196/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0739
# Epoch 197/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0740
# Epoch 198/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0661
# Epoch 199/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0702
# Epoch 200/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0691
# Epoch 201/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0667
# Epoch 202/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0580
# Epoch 203/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0589
# Epoch 204/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0564
# Epoch 205/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0574
# Epoch 206/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0538
# Epoch 207/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0563
# Epoch 208/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0518
# Epoch 209/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0488
# Epoch 210/300
# 13/13 [==============================] - ETA: 0s - loss: 0.045 - 0s 1ms/step - loss: 0.0482
# Epoch 211/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0442
# Epoch 212/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0450
# Epoch 213/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0425
# Epoch 214/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0396
# Epoch 215/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0390
# Epoch 216/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0383
# Epoch 217/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0368
# Epoch 218/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0337
# Epoch 219/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0327
# Epoch 220/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0321
# Epoch 221/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0315
# Epoch 222/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0295
# Epoch 223/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0299
# Epoch 224/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 225/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 226/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 227/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0240
# Epoch 228/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0240
# Epoch 229/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0231
# Epoch 230/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 231/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 232/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0190
# Epoch 233/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0200
# Epoch 234/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0190
# Epoch 235/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0177
# Epoch 236/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 237/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0171
# Epoch 238/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0154
# Epoch 239/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 240/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0148
# Epoch 241/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 242/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 243/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 244/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 245/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 246/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 247/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 248/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0098
# Epoch 249/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0097
# Epoch 250/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 251/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 252/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 253/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0081
# Epoch 254/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0076
# Epoch 255/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 256/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0067
# Epoch 257/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0068
# Epoch 258/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 259/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0063
# Epoch 260/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0057
# Epoch 261/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 262/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0049
# Epoch 263/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0050
# Epoch 264/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0047
# Epoch 265/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 266/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 267/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 268/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 269/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 270/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 271/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 272/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 273/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 274/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 275/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 276/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 277/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 278/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 279/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 280/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 281/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 282/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 283/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 284/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 285/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 286/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 287/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 288/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 289/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 290/300
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 291/300
# 13/13 [==============================] - 0s 2ms/step - loss: 9.8483e-04
# Epoch 292/300
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 293/300
# 13/13 [==============================] - 0s 1ms/step - loss: 8.2689e-04
# Epoch 294/300
# 13/13 [==============================] - 0s 2ms/step - loss: 8.3192e-04
# Epoch 295/300
# 13/13 [==============================] - ETA: 0s - loss: 9.0456e-0 - 0s 2ms/step - loss: 7.7276e-04
# Epoch 296/300
# 13/13 [==============================] - 0s 1ms/step - loss: 7.5126e-04
# Epoch 297/300
# 13/13 [==============================] - 0s 2ms/step - loss: 6.5531e-04
# Epoch 298/300
# 13/13 [==============================] - 0s 1ms/step - loss: 6.3459e-04
# Epoch 299/300
# 13/13 [==============================] - 0s 1ms/step - loss: 6.1980e-04
# Epoch 300/300
# 13/13 [==============================] - 0s 2ms/step - loss: 5.7545e-04

# %% [markdown]
# The model effectively passed the 300 steps to reduce the losses of the mean squared error from the height of 4.8619 to 5.7545e-04 and this model will be further looked into below.
#
#
# ### Testing the Train and Test Data Sets for Mean Squared Error
#
# To analyze the model both the train and test data sets the mean squared error on both the X_train and X_test sets and the Y_train and Y_test sets.

# %%
from sklearn.metrics import mean_squared_error
pred_train_linreg = model(X_train)
np.sqrt(mean_squared_error(pred_train_linreg,Y_train))
# Out:
# 0.023359057429782625

# %%
pred_test_linreg = model(X_test)
np.sqrt(mean_squared_error(pred_test_linreg,Y_test))
# Out:
# 0.023061801091608075

# %%
pred_ytrain_linreg = model(Y_train)
np.sqrt(mean_squared_error(X_train,pred_ytrain_linreg))
# Out:
# 8.871163835096487

# %%
pred_ytest_linreg = model(Y_test)
np.sqrt(mean_squared_error(X_test,pred_ytest_linreg))
# Out:
# 8.673330575545153

# %% [markdown]
# As viewable the mean squared error for the X and Y regardless of train and test sets are similar in outputs while using the model to pred the linear regression
#
# ### Plotting the Train and Test Data Sets
#
# We can then plot these to show the linear nature of the models outputs as see below:

# %%
#plotting the X_train and Y_train datasets using matplotlib scatter()
plt.plot(X_test, Y_test, label='actual')
plt.plot(model.predict(X_train), model.predict(Y_train), label='prediction')
plt.legend();

# %%
#plotting the X_test and Y_test datasets using matplotlib scatter()
plt.plot(X_train, Y_train, label='actual')
plt.plot(model.predict(X_test), model.predict(Y_test), label='prediction')
plt.legend();

# %% [markdown]
# ### Model Predicting using 4 Sample Points
#
# To use the model for four 4 random speed sample points of 5,10,15,20 and verify this by using the function f on the same points we can see that the model tends very closely to the expected outputs.

# %%
model.predict([5.0,10.0,15.0,20.0])
# Out:
# array([[15.883229],
#        [30.766434],
#        [45.64964 ],
#        [60.532845]], dtype=float32)

# %%
np.array([[f(i)] for i in [5.0, 10.0, 15.0, 20.0]])
# Out:
# array([[16.],
#        [31.],
#        [46.],
#        [61.]])

# %% [markdown]
# #### For the Sample Points 5,10,15,20
# Actual =    16,    31,    46,    61
#
# Predicted = 15.88, 30.77, 45.65, 60.53
# ### Evaluating the Model on Test and Training Sets
#
# The final evaluation of the testing and training allows using the evaluate() function. This samples the model and performs an evaluation of its accuracy. It tends towards zero allowing us to infer that the model is effective but allows for more improvement in the models performance.

# %%
#evaluating the test set
model.evaluate(X_test, Y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 5.3185e-04
# 0.0005318464827723801

# %%
#evaluating the train set
model.evaluate(X_train, Y_train)
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 5.4565e-04
# 0.0005456458311527967

# %% [markdown]
# ### Conclusion
#
# It is clear that the power production data set has a tendency for linear progression in that wind speed is a direct factor in the increase in wind power for the most part. This generally expected behaviour allowed the creation of two linear regression models on the wind speed sub set that tend to predict accurately the wind power and progress correctly using the Scikit and Keras packages.
#
# The functions will now be included in a webservice and hosted on docker as per this assignement.
#
#
# ### References
# Course content and resources.
# 1. GMIT (2018) “Quality assurance framework,” Accessed online at: https://www.gmit.ie/general/quality-assurance-framework.
# 2. I. McLoughlin (2020) “Using git for assessments,”. Accessed online at: https://github.com/ianmcloughlin/using-git-for-assessments/.
# 3. Sk Learn (2020) Supervised Learning Documentation. Accessed online at: https://scikit-learn.org/stable/supervised_learning.html#supervised-learning
# 4. w3schools (2020) Tutorials. Access online at: https://www.w3schools.com/
# 5. StackOverflow (2020) Various Stack Overflow Queries. Accessed online at: https://stackoverflow.com/
# 6. DataCamp (2020) Turning Machine Learning Models into APIs in Python. Accessed online at: https://www.datacamp.com/community/tutorials/machine-learning-models-api-python#comments
# 7. Keras (2020) Developer guides. Accessed online at: https://keras.io/guides/
# 8. Brownlee, J. (2016) Save and Load Machine Learning Models in Python with scikit-learn. Accessed online at: https://machinelearningmastery.com/save-load-machine-learning-models-python-scikit-learn/
# 9. Brownlee, J (2017) How to Train a Final Machine Learning Model. Accessed online at: https://machinelearningmastery.com/train-final-machine-learning-model/
# 10. Brownlee, J (2018) How to Make Predictions with scikit-learn. Accessed online at: https://machinelearningmastery.com/make-predictions-scikit-learn/
# 11. Docker Docs (2020) Docker Build Documentation. Accessed online at: https://docs.docker.com/engine/reference/commandline/build/
# 12. Tutorialspoint (2020) Keras - Model Evaluation and Model Prediction. Accessed online at: https://www.tutorialspoint.com/keras/keras_model_evaluation_and_prediction.htm
